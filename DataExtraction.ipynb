# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np

# %% [markdown]
# ## convert m2 to dataframe and merging files

# %%
def m2_to_df(m2_file_path,id=0):
    '''This function takes m2 file path as input and converts it to pandas dataframe'''

    m2 = open(m2_file_path).read().strip().split("\n\n")
    # Do not apply edits with these error types
    skip = {"noop", "UNK", "Um"}

    correct_sent_array = []
    incorrect_sent_array = []

    for sent in tqdm(m2):
        sent = sent.split("\n")
        incor_sent = sent[0].split()[1:] # Ignore "S "
        incorrect_sent_array.append(str(' '.join(incor_sent))) 
        cor_sent = incor_sent.copy()

        edits = sent[1:]
        offset = 0
        for edit in edits:
            edit = edit.split("|||")
            if edit[1] in skip: continue # Ignore certain edits
            coder = int(edit[-1])
            if coder != id: continue # Ignore other coders
            span = edit[0].split()[1:] # Ignore "A or S "
            start = int(span[0])
            end = int(span[1])
            cor = edit[2].split()
            cor_sent[start+offset:end+offset] = cor
            offset = offset-(end-start)+len(cor)
        correct_sent_array.append(str(' '.join(cor_sent)))

    df = pd.DataFrame()
    df["correct"] = correct_sent_array
    df["incorrect"] = incorrect_sent_array
    return df

# %%
m2_file_path = "2014\\test\\QALB-2014-L1-Test.m2"
df_test_2014 = m2_to_df(m2_file_path)

m2_file_path = "2014\\dev\\QALB-2014-L1-Dev.m2"
df_dev_2014 = m2_to_df(m2_file_path)

m2_file_path = "2014\\train\\QALB-2014-L1-Train (1).m2"
df_train_2014 = m2_to_df(m2_file_path)

m2_file_path = "2015\\test\\QALB-2015-L1-Test.m2"
df_test_2015_l1 = m2_to_df(m2_file_path)

m2_file_path = "2015\\test\\QALB-2015-L2-Test.m2"
df_test_2015_l2 = m2_to_df(m2_file_path)

m2_file_path = "2015\\dev\\QALB-2015-L2-Dev.m2"
df_dev_2015 = m2_to_df(m2_file_path)

m2_file_path = "2015\\train\\QALB-2015-L2-Train.m2"
df_train_2015 = m2_to_df(m2_file_path)
# Out:
# 100%|██████████| 968/968 [00:00<00:00, 17276.08it/s]
# 100%|██████████| 1017/1017 [00:00<00:00, 21172.73it/s]
# 100%|██████████| 19411/19411 [00:00<00:00, 23059.82it/s]
# 100%|██████████| 920/920 [00:00<00:00, 22971.54it/s]
# 100%|██████████| 158/158 [00:00<00:00, 6581.52it/s]
# 100%|██████████| 154/154 [00:00<00:00, 9620.97it/s]
# 100%|██████████| 310/310 [00:00<00:00, 9826.66it/s]

# %%
dataframes = [df_dev_2014, df_dev_2015, df_test_2014, df_test_2015_l1, df_test_2015_l2, df_train_2014, df_train_2015]
final_df = pd.concat(dataframes)
# Out:
#                                                correct  \
# 0    سبحان الله ، الحكام العرب سيموت على الكرسي ليظ...
# 1    النصر آت لا محال إن شاء الله . من يؤمن بالله و...
# 2    إلى كل شخص يعتقد أن بشار الأسد سوف يخرج من سور...
# 3    الأسد وعصابته - لحد الآن - غير مستوعبين أنه رح...
# 4    النظام الأسدي تجاوز حتى ما فعله معمر القذافي ف...
# ..                                                 ...
# 305  حوار عن " الشرعية الدولية " . في البرنامج " ال...
# 306  استمر دكتور جمال قريب إلى نهاية محاضرته أن يصف...
# 307  أصبحت اللغة العربية في هذا العصر موضوع اهتمام ...
# 308  الأقلية الفلسطينية في إسرائيل . حضرت محاضرة لل...
# 309  محاضرة : دكتور جمال . في يوم الجمعة 17 أكتوبر ...
#
#                                              incorrect
# 0    سبحان الله الحكام العرب سيموت على الكرسي ليضهر...
# 1    النصر آت لا محال انشاء الله من يؤمن بالله والي...
# 2    الى كل شخص يعتقد ان بشار الاسد سوف يخرج من سور...
# 3    الأسد وعصابته لحد الآن غير مستوعبين إن و رح ين...
# 4    النظام الأسدي تجاوز حتى ما فعله معمر القذافي ف...
# ..                                                 ...
# 305  حوار عن " الشرعية الدولية " في البرنامج " الات...
# 306  استمر دكتور جمال قريب من نهاية محاضرته أن يصف ...
# 307  أصبحت اللغة العربية في ھذا العصر موضوع إھتمام ...
# 308  الأقل ة الفلسط ن ة ف إسرائ ل حضرت محاضرة للأست...
# 309  محاضرة : دكتور جمال في يوم الجمعة ١٧ أكتوبر ، ...
#
# [22938 rows x 2 columns]

# %% [markdown]
# ## Check data

# %%
final_df.sample(5)
# Out:
#                                                  correct  \
# 12943  مقال يخلع القلب وأكثر ما فيها أنك وأمثالك رحلت...
# 15778  رحماك ربي قد غدا أمر البلد . . . في كف من كناه...
# 3546   يبنون مستوطنات ، الاسم ظاهر من عنوانه ، أي أنه...
# 15353  سوف أعلق ، وأظل أعلق ، وسأكون هذه المرة ضد مرت...
# 12986  الهدف واحد والتخطيط مدروس . لن تضرب إيران ولو ...
#
#                                                incorrect
# 12943  مقال يخلع القلب واكثر مافيها أنك وامثالك رحلتم...
# 15778  ر حماك رب ي قد غدا أمر البلد . . . في كف من كن...
# 3546   يبنون مستوطنات الاسم ظاهر من عنوانه اي انهم يس...
# 15353  سوف اعلق وأضل اعلق وساااكون هذيه المره ضد مرتز...
# 12986  الهدف واحد والتخطيط مدروس لن تضرب ايران ولوضرب...

# %%
def show_random_datapoints(n_samples,df):
    for i in range(n_samples):
        id = int(np.random.uniform(0,len(df)))

        if len(df['correct'].iloc[id].split())>5 and df['correct'].iloc[id] != df['incorrect'].iloc[id]:
            print(f"correct: {df['correct'].iloc[id]}")
            print(f"incorrect: {df['incorrect'].iloc[id]}")
            print('__'*100)

# %%
show_random_datapoints(10,final_df)
# Out:
# correct: الكاتب فهمي هويدي مثله مثل جميع من اتهموهم بالتسبب في هذه الفاجعة ، عندما تغافل عن عدم توجيه الاتهام لبابا الأقباط ومعاونيه ببذر الفتنة بين المصريين ، وتهيئة الفرصة لأعداء الوطن عندما تهكموا ، وصالوا ، وجالوا على الدين الإسلامي دون رقيب ولا حسيب .
# incorrect: الكاتب فهمي هويدي مثله مثل جميع من إتهمهم بالتسبب في هذه الفاجعه عندما تغافل عن عمد توجيه الإتهام لبابا الأقباط ومعاونيه ببذر الفتنه بين المصريين وتهيئة الفرصه لأعداء الوطن عندما تهكموا وصالوا وجالوا علي الدين الإسلامي دون رقيب ولا حسيب .
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# correct: الله ينصر كل من وقف أمام الحكومة وكل من عاداها ؛ لأنها حكومة فاشلة وخائنة للشعب والدين ، وحكومة رشوة ، وسرقة ، وفساد ، ولا تعبر أي شيء عن الدين أو الحكم الإسلامي . فأنا مع كل من يعاديها بأي وسيلة من الوسائل سواء كان سنيا أو شيعيا أو حتى يهوديا ! !
# incorrect: الله ينصر كل من وقف أمام الحكومه وكل من عاداها لأنه حكومه فاشله وخائنه للشعب والدين وحكومة رشوة وسرقة وفساد ولا تعبر أي شي عن الدين أو الحكم الاسلامي فأنا مع كل من يعاديها بأي وسيله من الوسائل سواء كان سني أو شيعي أو حتى يهودي ! ! .
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# correct: للأسف مهما زاد السعر ، فلا تزداد الدول المنتجة إلا تخلفا ، والدول المستهلكة إلا تقدما . . فتقدم الدول لا يقاس بكمية الإنتاج ، وإنما يقاس بكمية استهلاك الطاقة . . وإن خيرت لاخترت العيش في بلد تستهلك كميات من الطاقة على بلد ينتج ولا يستهلك الطاقة . فما بالك في بلد يستهلك ما ينتجه . . . . وسلامتها أم حسن ! !
# incorrect: للأســــف مهما زاد الســعر فلا تــزداد الدول المنتــــجه إلا تخـــلفا والدول المستهـــلكه إلا تقــدما . . فتقـــدم الـــدول لايقــــاس بكمية الإنتـــاج وإنمـــاء يقاس بكمـــية إستهـــلاك الطاقه . . وإن خــــ ي رت لأخ ـترت العيش فى بــلد تستهـــلك كميات من الطاقه على بــلد ينتـــج ولا يستهـــلك الطــاقه . فمابالك فى بلد يستهــلك ماينتجه . . . . وســـلامتهــا أ م حـــــسن . ! !
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# correct: الإيطاليون يدفعون الرشاوى لكي يبقى الهدوء سائدا وطالبان تقبل الرشاوى لكي تسكت على قوات الإحتلال . . . ما شاء الله على هكذا محتل وهكذا مقاومة . هل يسمح الإسلام بالسكوت على الكفار مقابل بضعة آلاف من الدولارات ! لكن لماذا نستغرب والطالبان معروفون كمهربي مخدرات ؟ أهذا هو ما يدعو له ديننا ؟
# incorrect: الايطاليون يدفعون الرشى لكي يبقى الهدوء سائدا وطالبان تقبل الرشى لكي تسكت على قوات الاحتلال . . . ماشاء الله على هكذا محتل وهكذا مقاومة . هل يسمح الاسلام بالسكوت على الكفار مقابل بضعة الاف من الدولارات لكن لماذا نستغرب والطالبان معروفون كمهربي مخدرات . اهذا هو مايدعو له ديننا
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# correct: الحمد لله هزمت مجموعة متطرفة تريد خطف اليمن إلى مستقبل مظلم ، والله هؤلاء هم أكبر خطر على الإسلام ، وبكل أسف يصلهم إمدادات مالية ضخمة من شيوخ السلفية في دول الجوار . الشعب اليمني تعب في ثورته ، ويجب ألا يترك الثمرة لدعاة التخلف والإرهاب .
# incorrect: الحمد لله هزمت مجموعه متطرفه تريد خطف اليمن الى مستقبل مظلم والله هؤلاء هم اكبر خطر على الاسلام و بكل اسف يصلهم امدادات ماليه ضخمه من شيوخ السلفيه فى دول الجوار . الشعب اليمنى تعب فى ثورته و يجب ألا يترك الثمره لدعاه التخلف و الارهاب .
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# correct: غباء معشعش . . بثمانية أيام وسوف يتم خنق الثورة السورية . . ثوري حقيقي جدا لم يلاحظ بأن الكتائب الأسدية ومعها الشبيحة النتنة ، وسنة من القتل بالشعب ولم تفلح طرقهم السفاحية ، والآن بثمانية أيام فقط ، ستشاهدون على الأرض هؤلاء المسلحين الذين لم يسلموا أنفسهم إما قتلى أو معتقلين ! ! يا للغباء والهبلنة . . الثوار بازدياد رغم القتل ، والله أكبر .
# incorrect: غباء معشعش . . بثمان أيام وسوف يتم خنق الثورة السورية . . بوري حقيقي جدا لم يلاحظ بأن الكتائب الأسدية ومعها الشبيحة النتنة وسنة من القتل بالشعب ولم تفلح طرقهم السفاحية والآن بثمان أيام فقط ستشاهدون على الأرض هؤلاء المسلحين الذين لم يسلموا أنفسهم إما قتلى أو معتقلين ! ! ياللغباء والهبلنة . . الثوار بإزدياد رغم القتل والله أكبر
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# correct: ليس غريبا أن يكون هذا حال من احتل البلاد بقوة الدبابات . إنه صنيعة المخابرات الأمريكية ، ولا غرابة أن يسعى إلى رهن البلاد للإرادة الأمريكية ؛ وبالتالي القضاء على حلم مليار مسلم بامتلاك قوة الردع النووي أمام غطرسة إسرائيل ، وحاميتها أمريكا ، والغرب عموما لحقدهم الدفين على الإسلام والمسلمين .
# incorrect: ليس غريبا ان يكون هذا حال من احتل البلاد بقوة الدبابات . إنه صنيعة المخابرات الامريكيه ولاغرابة ان بسعى الى رهن البلاد للارداة الامريكيه وبالتالي القضاء على حلم مليار مسلم بامتلاك قوة الردع النووي امام غطرسة اسرائيل وحاميتها امريكا والغرب عموما لحقدهم الدفين على الاسلام والمسلمين
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# correct: إن كان النظام ديمقراطيا ، وإن كان نظاما دكتاتوريا ، هذا لا يعني شيئا لمن يخطط ليل نهار ، لهدم الأمة العربية بأيدي عربية . منهم يعي ما يفعل ، ومنهم من يطبق المثل العربي الذي يقول : إذا جنوا جماعتك عقلك ما يفيدك . بس لي عتب عليكم يا جزيرة ، أنتم شو تعملون ؟ اتقوا الله فينا ، ترى في يوم حساب ، الله كبير .
# incorrect: ان كان النظام ديمقراطي وان كان نظام دكتاتوري هذا لايعني شئ لمن يخطط ليل نهار لهدم الامه العربية يايدي عربية منهم يعي مايفعل ومنهم من يطبق المثل العربي الي بيقول اذا انجنو جماعتك عقلك مايفيدك بس الي عتب عليكوم ياجزيرة انتم شو بتعملو اتغو الله فينا تره في يوم حساب اله كبير
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# correct: مكافأة على تطبيق مصر للعلمانية المطلقة بقيادة الإخوان ، صرفا للأنظار عن الإسلام الحقيقي الذي تخاف منه أمريكا والغرب . قامت صنيعة الغرب قطر بمكافأة نظام مرسي العلماني على جهوده في تضييع الإسلام في هذا الزمان ، ولكن دين الله سيظهر ولو كره المجرمون .
# incorrect: مكافأة على تطبيق مصر للعلمانية المطلقة بقيادة الاخوان ، صرفا للأنظار عن الاسلام الحقيقي الذي تخاف منه أمريكا والغرب قامت صنيعة الغرب قطر بمكافأة نظام مرسي العلماني على جهوده في تضييع الاسلام في هذا الزمان ، ولكن دين الله سيظهر ولو كره المجرمون
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# correct: على أي أساس تقولون شهيد ؟ هل قتل المدنيين ، وتفجير الأسواق ، وإثارة الرعب والفساد عمل جيد ؟ ماذا قدم هؤلاء القتلة سوى الخراب ؟ ما هو مشروعهم ، ما هي أهدافهم ؟ من خول لهم التحدث باسم المسلمين وقتل المسلمين ، وغيرهم ؟ هذا الفكر التكفيري والدموي ، والعبثي هو أكبر خطر علينا .
# incorrect: على أي أساس تقولوا شهيد ؟ هل قتل المدنيين ، وتفجير الأسواق وإثارة الرعب والفساد عمل جيد ؟ ماذا قدم هؤلاء القتلة سوى الخراب ؟ ما هو مشروعهم ، ما هي أهدافهم ؟ من خولهم التحدث باسم المسلمين وقتل المسلمين وغيرهم ؟ هذا الفكر التكفيري والدموي والعبثي هو أكبر خطر علينا
# ________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
final_df.to_csv('MergedDataset.csv',index=False)
